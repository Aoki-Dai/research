# %% [markdown]
# ## 全データで学習する
#
# 以下のセルを実行すると、全74万件のデータで学習
# →一時間くらいかかる

# %%
# 全データで学習（コメントアウトを解除して実行）

print("全データでWord2Vecモデルを学習中...")

# 全データを使用
full_corpus = TokenizedCorpus(ds['train'], max_docs=None)

# より大規模なモデル
full_model = Word2Vec(
    sentences=full_corpus,
    vector_size=300,
    window=5,
    min_count=10,           # 出現回数の閾値を上げる
    workers=8,              # ワーカー数を増やす
    sg=1,                   # Skip-gramを使用（精度重視）
    epochs=5,
    seed=42
)

# 保存
full_model.save("../results/models/word2vec_wiki40b_full.model")
full_model.wv.save("../results/models/word2vec_wiki40b_full.wordvectors")

print(f"学習完了! 語彙数: {len(full_model.wv):,}語")
# Out:
# 2025-11-13 02:28:59,684 : INFO : collecting all words and their counts
# 2025-11-13 02:28:59,705 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 全データでWord2Vecモデルを学習中...
# 2025-11-13 02:29:05,351 : INFO : PROGRESS: at sentence #10000, processed 2418682 words, keeping 176535 word types
# 2025-11-13 02:29:10,981 : INFO : PROGRESS: at sentence #20000, processed 4805583 words, keeping 264426 word types
# 2025-11-13 02:29:16,681 : INFO : PROGRESS: at sentence #30000, processed 7255236 words, keeping 334098 word types
# 2025-11-13 02:29:22,543 : INFO : PROGRESS: at sentence #40000, processed 9664607 words, keeping 395249 word types
# 2025-11-13 02:29:28,061 : INFO : PROGRESS: at sentence #50000, processed 12081297 words, keeping 448430 word types
# 2025-11-13 02:29:33,797 : INFO : PROGRESS: at sentence #60000, processed 14598879 words, keeping 498551 word types
# 2025-11-13 02:29:39,859 : INFO : PROGRESS: at sentence #70000, processed 17077922 words, keeping 542880 word types
# 2025-11-13 02:29:45,912 : INFO : PROGRESS: at sentence #80000, processed 19625744 words, keeping 585659 word types
# 2025-11-13 02:29:51,932 : INFO : PROGRESS: at sentence #90000, processed 22077887 words, keeping 624612 word types
# 2025-11-13 02:29:57,633 : INFO : PROGRESS: at sentence #100000, processed 24521368 words, keeping 661432 word types
# 2025-11-13 02:30:03,158 : INFO : PROGRESS: at sentence #110000, processed 26910459 words, keeping 695443 word types
# 2025-11-13 02:30:08,867 : INFO : PROGRESS: at sentence #120000, processed 29325503 words, keeping 729124 word types
# 2025-11-13 02:30:15,117 : INFO : PROGRESS: at sentence #130000, processed 31760173 words, keeping 761085 word types
# 2025-11-13 02:30:20,565 : INFO : PROGRESS: at sentence #140000, processed 34206402 words, keeping 792032 word types
# 2025-11-13 02:30:25,897 : INFO : PROGRESS: at sentence #150000, processed 36683794 words, keeping 821279 word types
# 2025-11-13 02:30:31,154 : INFO : PROGRESS: at sentence #160000, processed 39146558 words, keeping 850013 word types
# 2025-11-13 02:30:36,507 : INFO : PROGRESS: at sentence #170000, processed 41624113 words, keeping 878057 word types
# 2025-11-13 02:30:41,613 : INFO : PROGRESS: at sentence #180000, processed 44017960 words, keeping 905159 word types
# 2025-11-13 02:30:46,814 : INFO : PROGRESS: at sentence #190000, processed 46452642 words, keeping 931464 word types
# 2025-11-13 02:30:52,049 : INFO : PROGRESS: at sentence #200000, processed 48910447 words, keeping 957313 word types
# 2025-11-13 02:30:57,351 : INFO : PROGRESS: at sentence #210000, processed 51397547 words, keeping 982947 word types
# 2025-11-13 02:31:02,476 : INFO : PROGRESS: at sentence #220000, processed 53827768 words, keeping 1007264 word types
# 2025-11-13 02:31:07,732 : INFO : PROGRESS: at sentence #230000, processed 56302282 words, keeping 1030885 word types
# 2025-11-13 02:31:12,879 : INFO : PROGRESS: at sentence #240000, processed 58697721 words, keeping 1054034 word types
# 2025-11-13 02:31:18,401 : INFO : PROGRESS: at sentence #250000, processed 61277552 words, keeping 1077733 word types
# 2025-11-13 02:31:23,650 : INFO : PROGRESS: at sentence #260000, processed 63762055 words, keeping 1100510 word types
# 2025-11-13 02:31:29,034 : INFO : PROGRESS: at sentence #270000, processed 66283597 words, keeping 1122438 word types
# 2025-11-13 02:31:34,344 : INFO : PROGRESS: at sentence #280000, processed 68786499 words, keeping 1145171 word types
# 2025-11-13 02:31:39,771 : INFO : PROGRESS: at sentence #290000, processed 71325388 words, keeping 1167034 word types
# 2025-11-13 02:31:45,074 : INFO : PROGRESS: at sentence #300000, processed 73828005 words, keeping 1187148 word types
# 2025-11-13 02:31:50,508 : INFO : PROGRESS: at sentence #310000, processed 76364330 words, keeping 1208460 word types
# 2025-11-13 02:31:55,670 : INFO : PROGRESS: at sentence #320000, processed 78787760 words, keeping 1227989 word types
# 2025-11-13 02:32:00,976 : INFO : PROGRESS: at sentence #330000, processed 81289611 words, keeping 1247657 word types
# 2025-11-13 02:32:06,331 : INFO : PROGRESS: at sentence #340000, processed 83815134 words, keeping 1266521 word types
# 2025-11-13 02:32:11,575 : INFO : PROGRESS: at sentence #350000, processed 86249761 words, keeping 1285587 word types
# 2025-11-13 02:32:16,929 : INFO : PROGRESS: at sentence #360000, processed 88771019 words, keeping 1305717 word types
# 2025-11-13 02:32:22,094 : INFO : PROGRESS: at sentence #370000, processed 91210210 words, keeping 1324370 word types
# 2025-11-13 02:32:27,167 : INFO : PROGRESS: at sentence #380000, processed 93609998 words, keeping 1342545 word types
# 2025-11-13 02:32:32,378 : INFO : PROGRESS: at sentence #390000, processed 96018508 words, keeping 1360087 word types
# 2025-11-13 02:32:37,466 : INFO : PROGRESS: at sentence #400000, processed 98420581 words, keeping 1377465 word types
# 2025-11-13 02:32:42,605 : INFO : PROGRESS: at sentence #410000, processed 100847171 words, keeping 1394566 word types
# 2025-11-13 02:32:47,831 : INFO : PROGRESS: at sentence #420000, processed 103282014 words, keeping 1411692 word types
# 2025-11-13 02:32:52,989 : INFO : PROGRESS: at sentence #430000, processed 105695288 words, keeping 1429029 word types
# 2025-11-13 02:32:58,179 : INFO : PROGRESS: at sentence #440000, processed 108118800 words, keeping 1445398 word types
# 2025-11-13 02:33:03,381 : INFO : PROGRESS: at sentence #450000, processed 110564103 words, keeping 1461920 word types
# 2025-11-13 02:33:08,635 : INFO : PROGRESS: at sentence #460000, processed 113033810 words, keeping 1478744 word types
# 2025-11-13 02:33:14,059 : INFO : PROGRESS: at sentence #470000, processed 115549236 words, keeping 1495957 word types
# 2025-11-13 02:33:19,379 : INFO : PROGRESS: at sentence #480000, processed 118061303 words, keeping 1512375 word types
# 2025-11-13 02:33:24,558 : INFO : PROGRESS: at sentence #490000, processed 120510069 words, keeping 1528065 word types
# 2025-11-13 02:33:29,540 : INFO : PROGRESS: at sentence #500000, processed 122859516 words, keeping 1543312 word types
# 2025-11-13 02:33:34,965 : INFO : PROGRESS: at sentence #510000, processed 125398690 words, keeping 1558839 word types
# 2025-11-13 02:33:40,013 : INFO : PROGRESS: at sentence #520000, processed 127781431 words, keeping 1573325 word types
# 2025-11-13 02:33:45,105 : INFO : PROGRESS: at sentence #530000, processed 130200743 words, keeping 1588769 word types
# 2025-11-13 02:33:50,213 : INFO : PROGRESS: at sentence #540000, processed 132572332 words, keeping 1603390 word types
# 2025-11-13 02:33:55,472 : INFO : PROGRESS: at sentence #550000, processed 135012890 words, keeping 1618314 word types
# 2025-11-13 02:34:00,841 : INFO : PROGRESS: at sentence #560000, processed 137554827 words, keeping 1633514 word types
# 2025-11-13 02:34:06,127 : INFO : PROGRESS: at sentence #570000, processed 140025169 words, keeping 1648464 word types
# 2025-11-13 02:34:11,636 : INFO : PROGRESS: at sentence #580000, processed 142613870 words, keeping 1663726 word types
# 2025-11-13 02:34:16,547 : INFO : PROGRESS: at sentence #590000, processed 144943847 words, keeping 1677631 word types
# 2025-11-13 02:34:21,749 : INFO : PROGRESS: at sentence #600000, processed 147381754 words, keeping 1691396 word types
# 2025-11-13 02:34:26,793 : INFO : PROGRESS: at sentence #610000, processed 149765302 words, keeping 1705112 word types
# 2025-11-13 02:34:31,948 : INFO : PROGRESS: at sentence #620000, processed 152199395 words, keeping 1719288 word types
# 2025-11-13 02:34:37,341 : INFO : PROGRESS: at sentence #630000, processed 154657420 words, keeping 1733847 word types
# 2025-11-13 02:34:42,765 : INFO : PROGRESS: at sentence #640000, processed 157156607 words, keeping 1747646 word types
# 2025-11-13 02:34:48,151 : INFO : PROGRESS: at sentence #650000, processed 159659830 words, keeping 1761872 word types
# 2025-11-13 02:34:53,343 : INFO : PROGRESS: at sentence #660000, processed 162112594 words, keeping 1774976 word types
# 2025-11-13 02:34:58,565 : INFO : PROGRESS: at sentence #670000, processed 164576882 words, keeping 1788774 word types
# 2025-11-13 02:35:03,598 : INFO : PROGRESS: at sentence #680000, processed 166939626 words, keeping 1801694 word types
# 2025-11-13 02:35:08,720 : INFO : PROGRESS: at sentence #690000, processed 169349495 words, keeping 1814300 word types
# 2025-11-13 02:35:13,896 : INFO : PROGRESS: at sentence #700000, processed 171767991 words, keeping 1827647 word types
# 2025-11-13 02:35:19,072 : INFO : PROGRESS: at sentence #710000, processed 174208335 words, keeping 1840717 word types
# 2025-11-13 02:35:24,763 : INFO : PROGRESS: at sentence #720000, processed 176698085 words, keeping 1853770 word types
# 2025-11-13 02:35:30,714 : INFO : PROGRESS: at sentence #730000, processed 179165759 words, keeping 1866791 word types
# 2025-11-13 02:35:36,462 : INFO : PROGRESS: at sentence #740000, processed 181664678 words, keeping 1879613 word types
# 2025-11-13 02:35:39,364 : INFO : collected 1886712 word types from a corpus of 183002224 raw words and 745311 sentences
# 2025-11-13 02:35:39,364 : INFO : Creating a fresh vocabulary
# 2025-11-13 02:35:39,778 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=10 retains 393381 unique words (20.85% of original 1886712, drops 1493331)', 'datetime': '2025-11-13T02:35:39.778608', 'gensim': '4.4.0', 'python': '3.13.9 (main, Oct 28 2025, 12:02:14) [Clang 20.1.4 ]', 'platform': 'macOS-26.1-arm64-arm-64bit-Mach-O', 'event': 'prepare_vocab'}
# 2025-11-13 02:35:39,778 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=10 leaves 179568798 word corpus (98.12% of original 183002224, drops 3433426)', 'datetime': '2025-11-13T02:35:39.778972', 'gensim': '4.4.0', 'python': '3.13.9 (main, Oct 28 2025, 12:02:14) [Clang 20.1.4 ]', 'platform': 'macOS-26.1-arm64-arm-64bit-Mach-O', 'event': 'prepare_vocab'}
# 2025-11-13 02:35:40,251 : INFO : deleting the raw counts dictionary of 1886712 items
# 2025-11-13 02:35:40,269 : INFO : sample=0.001 downsamples 18 most-common words
# 2025-11-13 02:35:40,269 : INFO : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 154229515.6205603 word corpus (85.9%% of prior 179568798)', 'datetime': '2025-11-13T02:35:40.269657', 'gensim': '4.4.0', 'python': '3.13.9 (main, Oct 28 2025, 12:02:14) [Clang 20.1.4 ]', 'platform': 'macOS-26.1-arm64-arm-64bit-Mach-O', 'event': 'prepare_vocab'}
# 2025-11-13 02:35:41,049 : INFO : estimated required memory for 393381 words and 300 dimensions: 1140804900 bytes
# 2025-11-13 02:35:41,050 : INFO : resetting layer weights
# 2025-11-13 02:35:41,309 : INFO : Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2025-11-13T02:35:41.309693', 'gensim': '4.4.0', 'python': '3.13.9 (main, Oct 28 2025, 12:02:14) [Clang 20.1.4 ]', 'platform': 'macOS-26.1-arm64-arm-64bit-Mach-O', 'event': 'build_vocab'}
# 2025-11-13 02:35:41,310 : INFO : Word2Vec lifecycle event {'msg': 'training model with 8 workers on 393381 vocabulary and 300 features, using sg=1 hs=0 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2025-11-13T02:35:41.310094', 'gensim': '4.4.0', 'python': '3.13.9 (main, Oct 28 2025, 12:02:14) [Clang 20.1.4 ]', 'platform': 'macOS-26.1-arm64-arm-64bit-Mach-O', 'event': 'train'}
# 2025-11-13 02:35:42,320 : INFO : EPOCH 0 - PROGRESS: at 0.17% examples, 260497 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:35:43,343 : INFO : EPOCH 0 - PROGRESS: at 0.38% examples, 274682 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:35:44,364 : INFO : EPOCH 0 - PROGRESS: at 0.58% examples, 278605 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:35:45,390 : INFO : EPOCH 0 - PROGRESS: at 0.78% examples, 280967 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:35:46,410 : INFO : EPOCH 0 - PROGRESS: at 0.98% examples, 282367 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:35:47,432 : INFO : EPOCH 0 - PROGRESS: at 1.16% examples, 279421 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:35:48,436 : INFO : EPOCH 0 - PROGRESS: at 1.32% examples, 279197 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:35:49,437 : INFO : EPOCH 0 - PROGRESS: at 1.48% examples, 280132 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:35:50,438 : INFO : EPOCH 0 - PROGRESS: at 1.68% examples, 280614 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:35:51,439 : INFO : EPOCH 0 - PROGRESS: at 1.86% examples, 281093 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:35:52,456 : INFO : EPOCH 0 - PROGRESS: at 2.06% examples, 281425 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:35:53,469 : INFO : EPOCH 0 - PROGRESS: at 2.26% examples, 282008 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:35:54,472 : INFO : EPOCH 0 - PROGRESS: at 2.47% examples, 282277 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:35:55,477 : INFO : EPOCH 0 - PROGRESS: at 2.66% examples, 282644 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:35:56,485 : INFO : EPOCH 0 - PROGRESS: at 2.86% examples, 282698 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:35:57,507 : INFO : EPOCH 0 - PROGRESS: at 3.05% examples, 282690 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:35:58,526 : INFO : EPOCH 0 - PROGRESS: at 3.25% examples, 283140 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:35:59,547 : INFO : EPOCH 0 - PROGRESS: at 3.44% examples, 283259 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:00,551 : INFO : EPOCH 0 - PROGRESS: at 3.60% examples, 282221 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:01,572 : INFO : EPOCH 0 - PROGRESS: at 3.78% examples, 281833 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:02,574 : INFO : EPOCH 0 - PROGRESS: at 3.97% examples, 281873 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:03,585 : INFO : EPOCH 0 - PROGRESS: at 4.15% examples, 281917 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:04,624 : INFO : EPOCH 0 - PROGRESS: at 4.34% examples, 281653 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:05,632 : INFO : EPOCH 0 - PROGRESS: at 4.53% examples, 281725 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:36:06,656 : INFO : EPOCH 0 - PROGRESS: at 4.71% examples, 281662 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:36:07,666 : INFO : EPOCH 0 - PROGRESS: at 4.90% examples, 281632 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:08,666 : INFO : EPOCH 0 - PROGRESS: at 5.08% examples, 281535 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:36:09,689 : INFO : EPOCH 0 - PROGRESS: at 5.27% examples, 281428 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:10,719 : INFO : EPOCH 0 - PROGRESS: at 5.46% examples, 281459 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:11,727 : INFO : EPOCH 0 - PROGRESS: at 5.66% examples, 281368 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:12,739 : INFO : EPOCH 0 - PROGRESS: at 5.85% examples, 281052 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:13,822 : INFO : EPOCH 0 - PROGRESS: at 6.05% examples, 280550 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:14,845 : INFO : EPOCH 0 - PROGRESS: at 6.22% examples, 280386 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:15,856 : INFO : EPOCH 0 - PROGRESS: at 6.40% examples, 280265 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:16,868 : INFO : EPOCH 0 - PROGRESS: at 6.59% examples, 280184 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:17,885 : INFO : EPOCH 0 - PROGRESS: at 6.78% examples, 280176 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:18,915 : INFO : EPOCH 0 - PROGRESS: at 6.97% examples, 280170 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:19,944 : INFO : EPOCH 0 - PROGRESS: at 7.15% examples, 280195 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:20,961 : INFO : EPOCH 0 - PROGRESS: at 7.32% examples, 280303 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:21,969 : INFO : EPOCH 0 - PROGRESS: at 7.50% examples, 280098 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:36:22,980 : INFO : EPOCH 0 - PROGRESS: at 7.67% examples, 280119 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:23,987 : INFO : EPOCH 0 - PROGRESS: at 7.85% examples, 280011 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:25,007 : INFO : EPOCH 0 - PROGRESS: at 8.03% examples, 279976 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:26,030 : INFO : EPOCH 0 - PROGRESS: at 8.21% examples, 279926 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:27,040 : INFO : EPOCH 0 - PROGRESS: at 8.37% examples, 279746 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:28,076 : INFO : EPOCH 0 - PROGRESS: at 8.54% examples, 279187 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:29,082 : INFO : EPOCH 0 - PROGRESS: at 8.73% examples, 279192 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:30,096 : INFO : EPOCH 0 - PROGRESS: at 8.91% examples, 279184 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:31,097 : INFO : EPOCH 0 - PROGRESS: at 9.10% examples, 279189 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:36:32,107 : INFO : EPOCH 0 - PROGRESS: at 9.29% examples, 279189 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:33,109 : INFO : EPOCH 0 - PROGRESS: at 9.46% examples, 279184 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:34,135 : INFO : EPOCH 0 - PROGRESS: at 9.63% examples, 279149 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:35,149 : INFO : EPOCH 0 - PROGRESS: at 9.81% examples, 279072 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:36,175 : INFO : EPOCH 0 - PROGRESS: at 10.01% examples, 279050 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:37,202 : INFO : EPOCH 0 - PROGRESS: at 10.19% examples, 279012 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:36:38,213 : INFO : EPOCH 0 - PROGRESS: at 10.35% examples, 278562 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:39,221 : INFO : EPOCH 0 - PROGRESS: at 10.51% examples, 278649 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:40,226 : INFO : EPOCH 0 - PROGRESS: at 10.69% examples, 278548 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:41,248 : INFO : EPOCH 0 - PROGRESS: at 10.87% examples, 278605 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:36:42,253 : INFO : EPOCH 0 - PROGRESS: at 11.06% examples, 278670 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:43,272 : INFO : EPOCH 0 - PROGRESS: at 11.24% examples, 278610 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:44,289 : INFO : EPOCH 0 - PROGRESS: at 11.42% examples, 278586 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:36:45,306 : INFO : EPOCH 0 - PROGRESS: at 11.61% examples, 278621 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:46,335 : INFO : EPOCH 0 - PROGRESS: at 11.79% examples, 278587 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:36:47,356 : INFO : EPOCH 0 - PROGRESS: at 11.97% examples, 278579 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:48,364 : INFO : EPOCH 0 - PROGRESS: at 12.16% examples, 278600 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:49,377 : INFO : EPOCH 0 - PROGRESS: at 12.34% examples, 278637 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:50,390 : INFO : EPOCH 0 - PROGRESS: at 12.52% examples, 278278 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:51,390 : INFO : EPOCH 0 - PROGRESS: at 12.70% examples, 278261 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:52,391 : INFO : EPOCH 0 - PROGRESS: at 12.87% examples, 278250 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:53,409 : INFO : EPOCH 0 - PROGRESS: at 13.05% examples, 278301 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:54,427 : INFO : EPOCH 0 - PROGRESS: at 13.25% examples, 278250 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:55,435 : INFO : EPOCH 0 - PROGRESS: at 13.43% examples, 278228 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:56,471 : INFO : EPOCH 0 - PROGRESS: at 13.61% examples, 278234 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:57,479 : INFO : EPOCH 0 - PROGRESS: at 13.80% examples, 278028 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:36:58,504 : INFO : EPOCH 0 - PROGRESS: at 13.99% examples, 278055 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:36:59,520 : INFO : EPOCH 0 - PROGRESS: at 14.19% examples, 278064 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:37:00,530 : INFO : EPOCH 0 - PROGRESS: at 14.36% examples, 277902 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:37:01,554 : INFO : EPOCH 0 - PROGRESS: at 14.55% examples, 277909 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:37:02,572 : INFO : EPOCH 0 - PROGRESS: at 14.73% examples, 277925 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:37:03,587 : INFO : EPOCH 0 - PROGRESS: at 14.93% examples, 277955 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:37:04,603 : INFO : EPOCH 0 - PROGRESS: at 15.10% examples, 277974 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:37:05,610 : INFO : EPOCH 0 - PROGRESS: at 15.28% examples, 278007 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:37:06,622 : INFO : EPOCH 0 - PROGRESS: at 15.48% examples, 278035 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:37:07,628 : INFO : EPOCH 0 - PROGRESS: at 15.66% examples, 278061 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:37:08,649 : INFO : EPOCH 0 - PROGRESS: at 15.85% examples, 278095 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:37:09,662 : INFO : EPOCH 0 - PROGRESS: at 16.05% examples, 278154 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:37:10,677 : INFO : EPOCH 0 - PROGRESS: at 16.26% examples, 278209 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:37:11,678 : INFO : EPOCH 0 - PROGRESS: at 16.43% examples, 278184 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:37:12,689 : INFO : EPOCH 0 - PROGRESS: at 16.62% examples, 278236 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:37:13,741 : INFO : EPOCH 0 - PROGRESS: at 16.80% examples, 278167 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:37:14,747 : INFO : EPOCH 0 - PROGRESS: at 16.99% examples, 278123 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:37:15,758 : INFO : EPOCH 0 - PROGRESS: at 17.18% examples, 278168 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:37:16,772 : INFO : EPOCH 0 - PROGRESS: at 17.35% examples, 278240 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:37:17,799 : INFO : EPOCH 0 - PROGRESS: at 17.55% examples, 278289 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:37:18,812 : INFO : EPOCH 0 - PROGRESS: at 17.74% examples, 278340 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:37:19,813 : INFO : EPOCH 0 - PROGRESS: at 17.92% examples, 278394 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:37:20,828 : INFO : EPOCH 0 - PROGRESS: at 18.12% examples, 278394 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:37:21,848 : INFO : EPOCH 0 - PROGRESS: at 18.29% examples, 278414 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:37:22,862 : INFO : EPOCH 0 - PROGRESS: at 18.48% examples, 278474 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:37:23,885 : INFO : EPOCH 0 - PROGRESS: at 18.66% examples, 278472 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:37:24,898 : INFO : EPOCH 0 - PROGRESS: at 18.86% examples, 278536 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:37:25,901 : INFO : EPOCH 0 - PROGRESS: at 19.05% examples, 278576 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:37:26,925 : INFO : EPOCH 0 - PROGRESS: at 19.23% examples, 278636 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:37:27,948 : INFO : EPOCH 0 - PROGRESS: at 19.41% examples, 278665 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:37:28,967 : INFO : EPOCH 0 - PROGRESS: at 19.60% examples, 278711 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:37:29,986 : INFO : EPOCH 0 - PROGRESS: at 19.78% examples, 278722 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:37:30,994 : INFO : EPOCH 0 - PROGRESS: at 19.95% examples, 278621 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:37:32,007 : INFO : EPOCH 0 - PROGRESS: at 20.13% examples, 278637 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:37:33,054 : INFO : EPOCH 0 - PROGRESS: at 20.30% examples, 278663 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:37:34,064 : INFO : EPOCH 0 - PROGRESS: at 20.49% examples, 278728 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:37:35,071 : INFO : EPOCH 0 - PROGRESS: at 20.68% examples, 278747 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:37:36,103 : INFO : EPOCH 0 - PROGRESS: at 20.86% examples, 278748 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:37:37,128 : INFO : EPOCH 0 - PROGRESS: at 21.04% examples, 278764 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:37:38,150 : INFO : EPOCH 0 - PROGRESS: at 21.24% examples, 278829 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:37:39,167 : INFO : EPOCH 0 - PROGRESS: at 21.44% examples, 278867 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:37:40,187 : INFO : EPOCH 0 - PROGRESS: at 21.61% examples, 278911 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:37:41,213 : INFO : EPOCH 0 - PROGRESS: at 21.79% examples, 278929 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:37:42,225 : INFO : EPOCH 0 - PROGRESS: at 21.97% examples, 278995 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:37:43,241 : INFO : EPOCH 0 - PROGRESS: at 22.14% examples, 278903 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:37:44,251 : INFO : EPOCH 0 - PROGRESS: at 22.31% examples, 278930 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:37:45,252 : INFO : EPOCH 0 - PROGRESS: at 22.51% examples, 278963 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:37:46,261 : INFO : EPOCH 0 - PROGRESS: at 22.71% examples, 279006 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:37:47,282 : INFO : EPOCH 0 - PROGRESS: at 22.91% examples, 278995 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:37:48,288 : INFO : EPOCH 0 - PROGRESS: at 23.11% examples, 278975 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:37:49,321 : INFO : EPOCH 0 - PROGRESS: at 23.29% examples, 278920 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:37:50,342 : INFO : EPOCH 0 - PROGRESS: at 23.47% examples, 278872 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:37:51,375 : INFO : EPOCH 0 - PROGRESS: at 23.67% examples, 278899 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:37:52,400 : INFO : EPOCH 0 - PROGRESS: at 23.87% examples, 278943 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:37:53,423 : INFO : EPOCH 0 - PROGRESS: at 24.05% examples, 278966 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:37:54,443 : INFO : EPOCH 0 - PROGRESS: at 24.24% examples, 278998 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:37:55,455 : INFO : EPOCH 0 - PROGRESS: at 24.40% examples, 278992 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:37:56,475 : INFO : EPOCH 0 - PROGRESS: at 24.60% examples, 279022 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:37:57,486 : INFO : EPOCH 0 - PROGRESS: at 24.78% examples, 278945 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:37:58,493 : INFO : EPOCH 0 - PROGRESS: at 24.96% examples, 278989 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:37:59,501 : INFO : EPOCH 0 - PROGRESS: at 25.15% examples, 279030 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:38:00,507 : INFO : EPOCH 0 - PROGRESS: at 25.34% examples, 279043 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:01,528 : INFO : EPOCH 0 - PROGRESS: at 25.54% examples, 279009 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:02,551 : INFO : EPOCH 0 - PROGRESS: at 25.73% examples, 279047 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:03,582 : INFO : EPOCH 0 - PROGRESS: at 25.94% examples, 279084 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:04,582 : INFO : EPOCH 0 - PROGRESS: at 26.12% examples, 279125 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:05,585 : INFO : EPOCH 0 - PROGRESS: at 26.30% examples, 279154 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:06,589 : INFO : EPOCH 0 - PROGRESS: at 26.49% examples, 279154 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:07,595 : INFO : EPOCH 0 - PROGRESS: at 26.66% examples, 279164 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:08,624 : INFO : EPOCH 0 - PROGRESS: at 26.83% examples, 279130 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:09,638 : INFO : EPOCH 0 - PROGRESS: at 27.01% examples, 279184 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:38:10,683 : INFO : EPOCH 0 - PROGRESS: at 27.18% examples, 279080 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:11,713 : INFO : EPOCH 0 - PROGRESS: at 27.38% examples, 279100 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:12,721 : INFO : EPOCH 0 - PROGRESS: at 27.57% examples, 279150 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:13,739 : INFO : EPOCH 0 - PROGRESS: at 27.75% examples, 279177 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:14,742 : INFO : EPOCH 0 - PROGRESS: at 27.94% examples, 279217 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:15,766 : INFO : EPOCH 0 - PROGRESS: at 28.12% examples, 279223 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:16,770 : INFO : EPOCH 0 - PROGRESS: at 28.30% examples, 279250 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:17,791 : INFO : EPOCH 0 - PROGRESS: at 28.49% examples, 279289 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:38:18,803 : INFO : EPOCH 0 - PROGRESS: at 28.68% examples, 279324 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:19,809 : INFO : EPOCH 0 - PROGRESS: at 28.85% examples, 279258 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:20,828 : INFO : EPOCH 0 - PROGRESS: at 29.04% examples, 279308 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:21,843 : INFO : EPOCH 0 - PROGRESS: at 29.23% examples, 279329 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:22,875 : INFO : EPOCH 0 - PROGRESS: at 29.43% examples, 279336 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:23,876 : INFO : EPOCH 0 - PROGRESS: at 29.59% examples, 279286 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:38:24,887 : INFO : EPOCH 0 - PROGRESS: at 29.76% examples, 279309 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:25,906 : INFO : EPOCH 0 - PROGRESS: at 29.95% examples, 279301 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:38:26,926 : INFO : EPOCH 0 - PROGRESS: at 30.16% examples, 279312 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:27,940 : INFO : EPOCH 0 - PROGRESS: at 30.33% examples, 279319 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:28,945 : INFO : EPOCH 0 - PROGRESS: at 30.50% examples, 279323 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:29,953 : INFO : EPOCH 0 - PROGRESS: at 30.70% examples, 279353 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:30,978 : INFO : EPOCH 0 - PROGRESS: at 30.90% examples, 279376 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:31,988 : INFO : EPOCH 0 - PROGRESS: at 31.10% examples, 279394 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:33,012 : INFO : EPOCH 0 - PROGRESS: at 31.29% examples, 279439 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:34,021 : INFO : EPOCH 0 - PROGRESS: at 31.48% examples, 279468 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:35,042 : INFO : EPOCH 0 - PROGRESS: at 31.66% examples, 279365 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:36,075 : INFO : EPOCH 0 - PROGRESS: at 31.84% examples, 279379 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:38:37,083 : INFO : EPOCH 0 - PROGRESS: at 32.03% examples, 279388 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:38,090 : INFO : EPOCH 0 - PROGRESS: at 32.22% examples, 279406 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:38:39,119 : INFO : EPOCH 0 - PROGRESS: at 32.41% examples, 279446 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:40,133 : INFO : EPOCH 0 - PROGRESS: at 32.59% examples, 279460 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:41,133 : INFO : EPOCH 0 - PROGRESS: at 32.78% examples, 279491 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:42,160 : INFO : EPOCH 0 - PROGRESS: at 32.96% examples, 279526 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:38:43,174 : INFO : EPOCH 0 - PROGRESS: at 33.14% examples, 279551 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:44,189 : INFO : EPOCH 0 - PROGRESS: at 33.29% examples, 279567 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:45,199 : INFO : EPOCH 0 - PROGRESS: at 33.47% examples, 279585 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:46,221 : INFO : EPOCH 0 - PROGRESS: at 33.65% examples, 279615 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:38:47,228 : INFO : EPOCH 0 - PROGRESS: at 33.83% examples, 279487 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:48,236 : INFO : EPOCH 0 - PROGRESS: at 34.01% examples, 279487 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:49,237 : INFO : EPOCH 0 - PROGRESS: at 34.20% examples, 279514 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:50,243 : INFO : EPOCH 0 - PROGRESS: at 34.37% examples, 279532 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:51,251 : INFO : EPOCH 0 - PROGRESS: at 34.55% examples, 279552 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:52,271 : INFO : EPOCH 0 - PROGRESS: at 34.75% examples, 279576 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:38:53,274 : INFO : EPOCH 0 - PROGRESS: at 34.92% examples, 279593 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:54,279 : INFO : EPOCH 0 - PROGRESS: at 35.11% examples, 279605 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:55,288 : INFO : EPOCH 0 - PROGRESS: at 35.28% examples, 279604 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:56,293 : INFO : EPOCH 0 - PROGRESS: at 35.45% examples, 279624 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:57,307 : INFO : EPOCH 0 - PROGRESS: at 35.63% examples, 279608 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:38:58,351 : INFO : EPOCH 0 - PROGRESS: at 35.80% examples, 279594 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:38:59,357 : INFO : EPOCH 0 - PROGRESS: at 35.98% examples, 279582 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:00,358 : INFO : EPOCH 0 - PROGRESS: at 36.17% examples, 279592 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:01,363 : INFO : EPOCH 0 - PROGRESS: at 36.35% examples, 279632 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:02,407 : INFO : EPOCH 0 - PROGRESS: at 36.53% examples, 279633 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:03,421 : INFO : EPOCH 0 - PROGRESS: at 36.72% examples, 279662 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:04,448 : INFO : EPOCH 0 - PROGRESS: at 36.91% examples, 279703 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:39:05,478 : INFO : EPOCH 0 - PROGRESS: at 37.11% examples, 279712 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:06,488 : INFO : EPOCH 0 - PROGRESS: at 37.28% examples, 279710 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:07,517 : INFO : EPOCH 0 - PROGRESS: at 37.47% examples, 279727 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:39:08,546 : INFO : EPOCH 0 - PROGRESS: at 37.66% examples, 279740 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:09,558 : INFO : EPOCH 0 - PROGRESS: at 37.86% examples, 279762 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:39:10,591 : INFO : EPOCH 0 - PROGRESS: at 38.02% examples, 279770 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:11,619 : INFO : EPOCH 0 - PROGRESS: at 38.21% examples, 279797 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:12,637 : INFO : EPOCH 0 - PROGRESS: at 38.36% examples, 279739 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:13,663 : INFO : EPOCH 0 - PROGRESS: at 38.55% examples, 279763 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:14,717 : INFO : EPOCH 0 - PROGRESS: at 38.74% examples, 279752 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:15,724 : INFO : EPOCH 0 - PROGRESS: at 38.93% examples, 279786 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:16,736 : INFO : EPOCH 0 - PROGRESS: at 39.10% examples, 279809 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:17,739 : INFO : EPOCH 0 - PROGRESS: at 39.29% examples, 279834 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:18,748 : INFO : EPOCH 0 - PROGRESS: at 39.46% examples, 279856 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:39:19,767 : INFO : EPOCH 0 - PROGRESS: at 39.66% examples, 279876 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:20,797 : INFO : EPOCH 0 - PROGRESS: at 39.85% examples, 279857 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:21,829 : INFO : EPOCH 0 - PROGRESS: at 40.03% examples, 279882 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:39:22,850 : INFO : EPOCH 0 - PROGRESS: at 40.22% examples, 279904 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:23,877 : INFO : EPOCH 0 - PROGRESS: at 40.41% examples, 279934 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:24,901 : INFO : EPOCH 0 - PROGRESS: at 40.59% examples, 279935 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:25,913 : INFO : EPOCH 0 - PROGRESS: at 40.77% examples, 279960 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:26,918 : INFO : EPOCH 0 - PROGRESS: at 40.95% examples, 279993 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:27,921 : INFO : EPOCH 0 - PROGRESS: at 41.12% examples, 279925 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:28,928 : INFO : EPOCH 0 - PROGRESS: at 41.30% examples, 279934 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:29,934 : INFO : EPOCH 0 - PROGRESS: at 41.48% examples, 279936 words/s, in_qsize 0, out_qsize 1
# 2025-11-13 02:39:30,963 : INFO : EPOCH 0 - PROGRESS: at 41.68% examples, 279980 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:31,976 : INFO : EPOCH 0 - PROGRESS: at 41.85% examples, 279984 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:33,011 : INFO : EPOCH 0 - PROGRESS: at 42.06% examples, 279997 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:34,027 : INFO : EPOCH 0 - PROGRESS: at 42.24% examples, 280006 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:35,041 : INFO : EPOCH 0 - PROGRESS: at 42.43% examples, 280012 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:36,041 : INFO : EPOCH 0 - PROGRESS: at 42.61% examples, 280022 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:37,056 : INFO : EPOCH 0 - PROGRESS: at 42.80% examples, 280029 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:38,139 : INFO : EPOCH 0 - PROGRESS: at 43.01% examples, 279988 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:39,142 : INFO : EPOCH 0 - PROGRESS: at 43.20% examples, 280000 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:40,161 : INFO : EPOCH 0 - PROGRESS: at 43.37% examples, 279909 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:41,187 : INFO : EPOCH 0 - PROGRESS: at 43.54% examples, 279912 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:42,222 : INFO : EPOCH 0 - PROGRESS: at 43.70% examples, 279907 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:43,229 : INFO : EPOCH 0 - PROGRESS: at 43.90% examples, 279937 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:44,237 : INFO : EPOCH 0 - PROGRESS: at 44.08% examples, 279957 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:45,247 : INFO : EPOCH 0 - PROGRESS: at 44.27% examples, 279969 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:39:46,255 : INFO : EPOCH 0 - PROGRESS: at 44.44% examples, 279986 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:47,258 : INFO : EPOCH 0 - PROGRESS: at 44.62% examples, 279988 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:48,277 : INFO : EPOCH 0 - PROGRESS: at 44.81% examples, 279971 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:39:49,279 : INFO : EPOCH 0 - PROGRESS: at 44.98% examples, 279993 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:39:50,321 : INFO : EPOCH 0 - PROGRESS: at 45.17% examples, 279968 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:51,340 : INFO : EPOCH 0 - PROGRESS: at 45.35% examples, 279951 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:52,365 : INFO : EPOCH 0 - PROGRESS: at 45.52% examples, 279959 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:53,381 : INFO : EPOCH 0 - PROGRESS: at 45.70% examples, 279959 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:54,397 : INFO : EPOCH 0 - PROGRESS: at 45.89% examples, 279964 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:55,402 : INFO : EPOCH 0 - PROGRESS: at 46.07% examples, 279953 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:56,414 : INFO : EPOCH 0 - PROGRESS: at 46.23% examples, 279954 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:57,431 : INFO : EPOCH 0 - PROGRESS: at 46.43% examples, 279940 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:58,461 : INFO : EPOCH 0 - PROGRESS: at 46.64% examples, 279972 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:39:59,478 : INFO : EPOCH 0 - PROGRESS: at 46.83% examples, 279986 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:40:00,500 : INFO : EPOCH 0 - PROGRESS: at 47.01% examples, 279911 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:40:01,516 : INFO : EPOCH 0 - PROGRESS: at 47.18% examples, 279938 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:40:02,553 : INFO : EPOCH 0 - PROGRESS: at 47.38% examples, 279957 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:40:03,576 : INFO : EPOCH 0 - PROGRESS: at 47.57% examples, 279964 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:40:04,582 : INFO : EPOCH 0 - PROGRESS: at 47.75% examples, 279980 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:40:05,599 : INFO : EPOCH 0 - PROGRESS: at 47.96% examples, 279996 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:40:06,615 : INFO : EPOCH 0 - PROGRESS: at 48.14% examples, 280023 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:40:07,628 : INFO : EPOCH 0 - PROGRESS: at 48.30% examples, 280015 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:40:08,642 : INFO : EPOCH 0 - PROGRESS: at 48.47% examples, 280003 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:40:09,651 : INFO : EPOCH 0 - PROGRESS: at 48.64% examples, 280013 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:40:10,683 : INFO : EPOCH 0 - PROGRESS: at 48.83% examples, 280025 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:40:11,688 : INFO : EPOCH 0 - PROGRESS: at 49.02% examples, 280037 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:40:12,713 : INFO : EPOCH 0 - PROGRESS: at 49.20% examples, 279980 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:40:13,734 : INFO : EPOCH 0 - PROGRESS: at 49.41% examples, 280007 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:40:14,766 : INFO : EPOCH 0 - PROGRESS: at 49.59% examples, 280011 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:40:15,772 : INFO : EPOCH 0 - PROGRESS: at 49.79% examples, 280031 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:40:16,779 : INFO : EPOCH 0 - PROGRESS: at 49.97% examples, 280043 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:40:17,782 : INFO : EPOCH 0 - PROGRESS: at 50.16% examples, 280053 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:40:18,800 : INFO : EPOCH 0 - PROGRESS: at 50.34% examples, 280044 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:40:19,819 : INFO : EPOCH 0 - PROGRESS: at 50.54% examples, 280043 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:40:20,821 : INFO : EPOCH 0 - PROGRESS: at 50.72% examples, 280033 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:40:21,837 : INFO : EPOCH 0 - PROGRESS: at 50.92% examples, 280049 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:40:22,845 : INFO : EPOCH 0 - PROGRESS: at 51.09% examples, 280065 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:40:23,861 : INFO : EPOCH 0 - PROGRESS: at 51.28% examples, 280057 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:40:24,863 : INFO : EPOCH 0 - PROGRESS: at 51.47% examples, 280082 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:40:25,876 : INFO : EPOCH 0 - PROGRESS: at 51.66% examples, 280082 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:40:26,891 : INFO : EPOCH 0 - PROGRESS: at 51.85% examples, 280083 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:40:27,918 : INFO : EPOCH 0 - PROGRESS: at 52.03% examples, 280027 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:40:28,946 : INFO : EPOCH 0 - PROGRESS: at 52.18% examples, 279817 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:40:29,964 : INFO : EPOCH 0 - PROGRESS: at 52.33% examples, 279579 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:40:30,986 : INFO : EPOCH 0 - PROGRESS: at 52.53% examples, 279581 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:40:31,990 : INFO : EPOCH 0 - PROGRESS: at 52.74% examples, 279697 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:40:33,012 : INFO : EPOCH 0 - PROGRESS: at 52.96% examples, 279837 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 02:40:34,027 : INFO : EPOCH 0 - PROGRESS: at 53.15% examples, 279887 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 02:40:35,034 : INFO : EPOCH 0 - PROGRESS: at 53.35% examples, 279996 words/s, in_qsize 0, out_qsize 0
# ...
# 2025-11-13 03:23:37,683 : INFO : EPOCH 4 - PROGRESS: at 78.21% examples, 304887 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:23:38,692 : INFO : EPOCH 4 - PROGRESS: at 78.42% examples, 304916 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:23:39,719 : INFO : EPOCH 4 - PROGRESS: at 78.65% examples, 304931 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:23:40,737 : INFO : EPOCH 4 - PROGRESS: at 78.85% examples, 304930 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:23:41,763 : INFO : EPOCH 4 - PROGRESS: at 79.05% examples, 304922 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:23:42,767 : INFO : EPOCH 4 - PROGRESS: at 79.28% examples, 304940 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:23:43,773 : INFO : EPOCH 4 - PROGRESS: at 79.47% examples, 304961 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:23:44,791 : INFO : EPOCH 4 - PROGRESS: at 79.67% examples, 304979 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:23:45,820 : INFO : EPOCH 4 - PROGRESS: at 79.87% examples, 304945 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:23:46,829 : INFO : EPOCH 4 - PROGRESS: at 80.09% examples, 304968 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:23:47,840 : INFO : EPOCH 4 - PROGRESS: at 80.29% examples, 304985 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 03:23:48,841 : INFO : EPOCH 4 - PROGRESS: at 80.49% examples, 304992 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 03:23:49,860 : INFO : EPOCH 4 - PROGRESS: at 80.70% examples, 305003 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:23:50,877 : INFO : EPOCH 4 - PROGRESS: at 80.91% examples, 305019 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:23:51,898 : INFO : EPOCH 4 - PROGRESS: at 81.12% examples, 305033 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:23:52,904 : INFO : EPOCH 4 - PROGRESS: at 81.32% examples, 305053 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 03:23:53,909 : INFO : EPOCH 4 - PROGRESS: at 81.53% examples, 305023 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:23:54,923 : INFO : EPOCH 4 - PROGRESS: at 81.74% examples, 305040 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:23:55,948 : INFO : EPOCH 4 - PROGRESS: at 81.96% examples, 305052 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 03:23:56,960 : INFO : EPOCH 4 - PROGRESS: at 82.16% examples, 305071 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:23:57,965 : INFO : EPOCH 4 - PROGRESS: at 82.36% examples, 305076 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 03:23:58,986 : INFO : EPOCH 4 - PROGRESS: at 82.57% examples, 305093 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:00,011 : INFO : EPOCH 4 - PROGRESS: at 82.78% examples, 305114 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 03:24:01,030 : INFO : EPOCH 4 - PROGRESS: at 82.98% examples, 305126 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:02,034 : INFO : EPOCH 4 - PROGRESS: at 83.19% examples, 305145 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:03,061 : INFO : EPOCH 4 - PROGRESS: at 83.40% examples, 305148 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:04,078 : INFO : EPOCH 4 - PROGRESS: at 83.62% examples, 305169 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:05,106 : INFO : EPOCH 4 - PROGRESS: at 83.81% examples, 305129 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:06,107 : INFO : EPOCH 4 - PROGRESS: at 84.01% examples, 305146 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:07,125 : INFO : EPOCH 4 - PROGRESS: at 84.21% examples, 305150 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:08,127 : INFO : EPOCH 4 - PROGRESS: at 84.41% examples, 305167 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:09,141 : INFO : EPOCH 4 - PROGRESS: at 84.59% examples, 305134 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:10,168 : INFO : EPOCH 4 - PROGRESS: at 84.81% examples, 305146 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:11,205 : INFO : EPOCH 4 - PROGRESS: at 84.99% examples, 305154 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:12,227 : INFO : EPOCH 4 - PROGRESS: at 85.20% examples, 305179 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:13,254 : INFO : EPOCH 4 - PROGRESS: at 85.38% examples, 305145 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:14,295 : INFO : EPOCH 4 - PROGRESS: at 85.59% examples, 305146 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:15,308 : INFO : EPOCH 4 - PROGRESS: at 85.79% examples, 305159 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:16,315 : INFO : EPOCH 4 - PROGRESS: at 86.00% examples, 305173 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 03:24:17,336 : INFO : EPOCH 4 - PROGRESS: at 86.19% examples, 305138 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:18,345 : INFO : EPOCH 4 - PROGRESS: at 86.38% examples, 305146 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:19,372 : INFO : EPOCH 4 - PROGRESS: at 86.58% examples, 305141 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 03:24:20,386 : INFO : EPOCH 4 - PROGRESS: at 86.79% examples, 305135 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:21,413 : INFO : EPOCH 4 - PROGRESS: at 86.99% examples, 305091 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:22,469 : INFO : EPOCH 4 - PROGRESS: at 87.16% examples, 305006 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:23,483 : INFO : EPOCH 4 - PROGRESS: at 87.36% examples, 305012 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:24,487 : INFO : EPOCH 4 - PROGRESS: at 87.58% examples, 305025 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:25,505 : INFO : EPOCH 4 - PROGRESS: at 87.78% examples, 305002 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:26,522 : INFO : EPOCH 4 - PROGRESS: at 87.97% examples, 305010 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:27,547 : INFO : EPOCH 4 - PROGRESS: at 88.17% examples, 305009 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:28,555 : INFO : EPOCH 4 - PROGRESS: at 88.36% examples, 305019 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 03:24:29,577 : INFO : EPOCH 4 - PROGRESS: at 88.58% examples, 305003 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:30,580 : INFO : EPOCH 4 - PROGRESS: at 88.76% examples, 305003 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 03:24:31,588 : INFO : EPOCH 4 - PROGRESS: at 88.97% examples, 305022 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:32,628 : INFO : EPOCH 4 - PROGRESS: at 89.16% examples, 305028 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:33,640 : INFO : EPOCH 4 - PROGRESS: at 89.38% examples, 305035 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:34,648 : INFO : EPOCH 4 - PROGRESS: at 89.57% examples, 305025 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 03:24:35,673 : INFO : EPOCH 4 - PROGRESS: at 89.78% examples, 305034 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 03:24:36,678 : INFO : EPOCH 4 - PROGRESS: at 89.99% examples, 305054 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:37,685 : INFO : EPOCH 4 - PROGRESS: at 90.20% examples, 305059 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 03:24:38,692 : INFO : EPOCH 4 - PROGRESS: at 90.41% examples, 305070 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:39,694 : INFO : EPOCH 4 - PROGRESS: at 90.59% examples, 305029 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:40,706 : INFO : EPOCH 4 - PROGRESS: at 90.82% examples, 305047 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 03:24:41,723 : INFO : EPOCH 4 - PROGRESS: at 91.03% examples, 305054 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:42,723 : INFO : EPOCH 4 - PROGRESS: at 91.24% examples, 305072 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:43,740 : INFO : EPOCH 4 - PROGRESS: at 91.45% examples, 305074 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:44,761 : INFO : EPOCH 4 - PROGRESS: at 91.66% examples, 305090 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:45,765 : INFO : EPOCH 4 - PROGRESS: at 91.88% examples, 305113 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 03:24:46,787 : INFO : EPOCH 4 - PROGRESS: at 92.09% examples, 305120 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:47,811 : INFO : EPOCH 4 - PROGRESS: at 92.30% examples, 305125 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:48,827 : INFO : EPOCH 4 - PROGRESS: at 92.49% examples, 305141 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:49,828 : INFO : EPOCH 4 - PROGRESS: at 92.69% examples, 305142 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:50,858 : INFO : EPOCH 4 - PROGRESS: at 92.89% examples, 305131 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:51,863 : INFO : EPOCH 4 - PROGRESS: at 93.10% examples, 305131 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:52,865 : INFO : EPOCH 4 - PROGRESS: at 93.28% examples, 305093 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:53,867 : INFO : EPOCH 4 - PROGRESS: at 93.48% examples, 305100 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:54,880 : INFO : EPOCH 4 - PROGRESS: at 93.69% examples, 305112 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:55,903 : INFO : EPOCH 4 - PROGRESS: at 93.90% examples, 305071 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:56,905 : INFO : EPOCH 4 - PROGRESS: at 94.10% examples, 305077 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 03:24:57,906 : INFO : EPOCH 4 - PROGRESS: at 94.29% examples, 305078 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:24:58,919 : INFO : EPOCH 4 - PROGRESS: at 94.51% examples, 305093 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 03:24:59,929 : INFO : EPOCH 4 - PROGRESS: at 94.70% examples, 305102 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:25:00,951 : INFO : EPOCH 4 - PROGRESS: at 94.89% examples, 305076 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:25:01,954 : INFO : EPOCH 4 - PROGRESS: at 95.10% examples, 305091 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:25:02,964 : INFO : EPOCH 4 - PROGRESS: at 95.32% examples, 305094 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:25:03,966 : INFO : EPOCH 4 - PROGRESS: at 95.52% examples, 305095 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:25:04,988 : INFO : EPOCH 4 - PROGRESS: at 95.71% examples, 305103 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:25:05,997 : INFO : EPOCH 4 - PROGRESS: at 95.90% examples, 305110 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:25:07,005 : INFO : EPOCH 4 - PROGRESS: at 96.09% examples, 305103 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:25:08,023 : INFO : EPOCH 4 - PROGRESS: at 96.29% examples, 305080 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:25:09,024 : INFO : EPOCH 4 - PROGRESS: at 96.50% examples, 305093 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:25:10,052 : INFO : EPOCH 4 - PROGRESS: at 96.70% examples, 305106 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:25:11,065 : INFO : EPOCH 4 - PROGRESS: at 96.90% examples, 305113 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:25:12,073 : INFO : EPOCH 4 - PROGRESS: at 97.09% examples, 305104 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 03:25:13,101 : INFO : EPOCH 4 - PROGRESS: at 97.28% examples, 305074 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:25:14,116 : INFO : EPOCH 4 - PROGRESS: at 97.48% examples, 305082 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:25:15,120 : INFO : EPOCH 4 - PROGRESS: at 97.69% examples, 305101 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:25:16,124 : INFO : EPOCH 4 - PROGRESS: at 97.90% examples, 305122 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:25:17,137 : INFO : EPOCH 4 - PROGRESS: at 98.12% examples, 305136 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 03:25:18,138 : INFO : EPOCH 4 - PROGRESS: at 98.33% examples, 305156 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:25:19,153 : INFO : EPOCH 4 - PROGRESS: at 98.53% examples, 305175 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:25:20,164 : INFO : EPOCH 4 - PROGRESS: at 98.71% examples, 305118 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:25:21,169 : INFO : EPOCH 4 - PROGRESS: at 98.91% examples, 305128 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 03:25:22,177 : INFO : EPOCH 4 - PROGRESS: at 99.09% examples, 305140 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:25:23,178 : INFO : EPOCH 4 - PROGRESS: at 99.28% examples, 305151 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:25:24,199 : INFO : EPOCH 4 - PROGRESS: at 99.49% examples, 305165 words/s, in_qsize 0, out_qsize 0
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 2025-11-13 03:25:25,220 : INFO : EPOCH 4 - PROGRESS: at 99.69% examples, 305180 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:25:26,244 : INFO : EPOCH 4 - PROGRESS: at 99.89% examples, 305189 words/s, in_qsize 0, out_qsize 0
# 2025-11-13 03:25:26,808 : INFO : EPOCH 4: training on 183002224 raw words (153849121 effective words) took 504.1s, 305199 effective words/s
# 2025-11-13 03:25:26,813 : INFO : Word2Vec lifecycle event {'msg': 'training on 915011120 raw words (769257301 effective words) took 2600.2s, 295848 effective words/s', 'datetime': '2025-11-13T03:25:26.813896', 'gensim': '4.4.0', 'python': '3.13.9 (main, Oct 28 2025, 12:02:14) [Clang 20.1.4 ]', 'platform': 'macOS-26.1-arm64-arm-64bit-Mach-O', 'event': 'train'}
# 2025-11-13 03:25:26,814 : INFO : Word2Vec lifecycle event {'params': 'Word2Vec<vocab=393381, vector_size=300, alpha=0.025>', 'datetime': '2025-11-13T03:25:26.814551', 'gensim': '4.4.0', 'python': '3.13.9 (main, Oct 28 2025, 12:02:14) [Clang 20.1.4 ]', 'platform': 'macOS-26.1-arm64-arm-64bit-Mach-O', 'event': 'created'}
# 2025-11-13 03:25:26,816 : INFO : Word2Vec lifecycle event {'fname_or_handle': '../results/models/word2vec_wiki40b_full.model', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2025-11-13T03:25:26.816934', 'gensim': '4.4.0', 'python': '3.13.9 (main, Oct 28 2025, 12:02:14) [Clang 20.1.4 ]', 'platform': 'macOS-26.1-arm64-arm-64bit-Mach-O', 'event': 'saving'}
# 2025-11-13 03:25:26,817 : INFO : storing np array 'vectors' to ../results/models/word2vec_wiki40b_full.model.wv.vectors.npy
# 2025-11-13 03:25:26,891 : INFO : storing np array 'syn1neg' to ../results/models/word2vec_wiki40b_full.model.syn1neg.npy
# 2025-11-13 03:25:26,957 : INFO : not storing attribute cum_table
# 2025-11-13 03:25:27,053 : INFO : saved ../results/models/word2vec_wiki40b_full.model
# 2025-11-13 03:25:27,054 : INFO : KeyedVectors lifecycle event {'fname_or_handle': '../results/models/word2vec_wiki40b_full.wordvectors', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2025-11-13T03:25:27.054309', 'gensim': '4.4.0', 'python': '3.13.9 (main, Oct 28 2025, 12:02:14) [Clang 20.1.4 ]', 'platform': 'macOS-26.1-arm64-arm-64bit-Mach-O', 'event': 'saving'}
# 2025-11-13 03:25:27,054 : INFO : storing np array 'vectors' to ../results/models/word2vec_wiki40b_full.wordvectors.vectors.npy
# 2025-11-13 03:25:27,160 : INFO : saved ../results/models/word2vec_wiki40b_full.wordvectors
# 学習完了! 語彙数: 393,381語

# %% [markdown]
# ## Fullモデルの読み込みと評価

# %%
# Fullモデルの読み込み
from gensim.models import Word2Vec, KeyedVectors
import os

# モデルパスの確認
full_model_path = "../results/models/word2vec_wiki40b_full.model"
full_wv_path = "../results/models/word2vec_wiki40b_full.wordvectors"

if os.path.exists(full_model_path):
    print("Fullモデルを読み込み中...")
    full_model = Word2Vec.load(full_model_path)
    print("✓ モデル読み込み完了")
    print(f"  語彙数: {len(full_model.wv):,}語")
    print(f"  ベクトル次元: {full_model.wv.vector_size}")
elif os.path.exists(full_wv_path):
    print("単語ベクトルのみ読み込み中...")
    full_model_wv = KeyedVectors.load(full_wv_path)
    print("✓ 単語ベクトル読み込み完了")
    print(f"  語彙数: {len(full_model_wv):,}語")
    print(f"  ベクトル次元: {full_model_wv.vector_size}")
    # 以降の評価用に変数を統一
    full_model = type('obj', (object,), {'wv': full_model_wv})()
else:
    print("⚠ Fullモデルが見つかりません")
    print(f"  期待パス: {full_model_path}")
    print("  先に全データで学習を実行してください")
# Out:
# 2025-11-13 13:19:21,218 : INFO : loading Word2Vec object from ../results/models/word2vec_wiki40b_full.model
# 2025-11-13 13:19:21,287 : INFO : loading wv recursively from ../results/models/word2vec_wiki40b_full.model.wv.* with mmap=None
# 2025-11-13 13:19:21,287 : INFO : loading vectors from ../results/models/word2vec_wiki40b_full.model.wv.vectors.npy with mmap=None
# Fullモデルを読み込み中...
# 2025-11-13 13:19:21,430 : INFO : loading syn1neg from ../results/models/word2vec_wiki40b_full.model.syn1neg.npy with mmap=None
# 2025-11-13 13:19:21,550 : INFO : setting ignored attribute cum_table to None
# 2025-11-13 13:19:22,193 : INFO : Word2Vec lifecycle event {'fname': '../results/models/word2vec_wiki40b_full.model', 'datetime': '2025-11-13T13:19:22.193434', 'gensim': '4.4.0', 'python': '3.13.9 (main, Oct 28 2025, 12:02:14) [Clang 20.1.4 ]', 'platform': 'macOS-26.1-arm64-arm-64bit-Mach-O', 'event': 'loaded'}
# ✓ モデル読み込み完了
#   語彙数: 393,381語
#   ベクトル次元: 300

# %%
# 基本的な類似語検索テスト
print("=" * 80)
print("類似語検索テスト（Fullモデル）")
print("=" * 80)

test_words = [
    "日本", "東京", "大阪", "京都",
    "コンピュータ", "プログラミング", "人工知能",
    "野球", "サッカー", "テニス",
    "音楽", "映画", "小説",
    "経済", "政治", "科学",
    "大学", "研究", "教育"
]

for word in test_words:
    if word in full_model.wv:
        print(f"\n【{word}】に類似する単語 (Top 5):")
        similar_words = full_model.wv.most_similar(word, topn=5)
        for i, (similar_word, score) in enumerate(similar_words, 1):
            print(f"  {i}. {similar_word:15s} (類似度: {score:.4f})")
    else:
        print(f"\n【{word}】は語彙に含まれていません")
# Out:
# ================================================================================
# 類似語検索テスト（Fullモデル）
# ================================================================================
#
# 【日本】に類似する単語 (Top 5):
#   1. 日本国内            (類似度: 0.6433)
#   2. 青年海外協力協会        (類似度: 0.4994)
#   3. 韓国              (類似度: 0.4994)
#   4. 作詩家             (類似度: 0.4973)
#   5. jbby            (類似度: 0.4912)
#
# 【東京】に類似する単語 (Top 5):
#   1. 大阪              (類似度: 0.6780)
#   2. 名古屋             (類似度: 0.6025)
#   3. 千歳高等学校          (類似度: 0.6024)
#   4. 都立              (類似度: 0.5992)
#   5. 品川              (類似度: 0.5848)
#
# 【大阪】に類似する単語 (Top 5):
#   1. 名古屋             (類似度: 0.7059)
#   2. 東京              (類似度: 0.6780)
#   3. 大阪市             (類似度: 0.6665)
#   4. 心斎橋             (類似度: 0.6508)
#   5. 神戸              (類似度: 0.6463)
#
# 【京都】に類似する単語 (Top 5):
#   1. 奈良              (類似度: 0.6762)
#   2. 京都市             (類似度: 0.6643)
#   3. 嵯峨野             (類似度: 0.6378)
#   4. 花灯路             (類似度: 0.6335)
#   5. 洛北              (類似度: 0.6178)
#
# 【コンピュータ】は語彙に含まれていません
#
# 【プログラミング】に類似する単語 (Top 5):
#   1. プログラミング言語       (類似度: 0.7367)
#   2. コンピュータ言語        (類似度: 0.6851)
#   3. 関数プログラミング       (類似度: 0.6810)
#   4. プログラミングパラダイム    (類似度: 0.6798)
#   5. 関数型プログラミング      (類似度: 0.6735)
#
# 【人工知能】に類似する単語 (Top 5):
#   1. ロボット工学          (類似度: 0.6671)
#   2. AI              (類似度: 0.6656)
#   3. ディープラーニング       (類似度: 0.6583)
#   4. 機械学習            (類似度: 0.6576)
#   5. ロドニー・ブルックス      (類似度: 0.6542)
#
# 【野球】に類似する単語 (Top 5):
#   1. ソフトボール          (類似度: 0.7287)
#   2. サッカー            (類似度: 0.6840)
#   3. 女子野球            (類似度: 0.6763)
#   4. 軟式野球            (類似度: 0.6739)
#   5. プロ野球            (類似度: 0.6728)
#
# 【サッカー】に類似する単語 (Top 5):
#   1. バスケットボール        (類似度: 0.7280)
#   2. ラグビー            (類似度: 0.7023)
#   3. バレーボール          (類似度: 0.6991)
#   4. 女子サッカー          (類似度: 0.6958)
#   5. フットボール          (類似度: 0.6916)
#
# 【テニス】に類似する単語 (Top 5):
#   1. 卓球              (類似度: 0.7315)
#   2. プロテニス           (類似度: 0.6574)
#   3. バドミントン          (類似度: 0.6554)
#   4. ウィンブルドン選手権      (類似度: 0.6414)
#   5. 女子テニス           (類似度: 0.6390)
#
# 【音楽】に類似する単語 (Top 5):
#   1. クラシック音楽         (類似度: 0.7611)
#   2. 民族音楽            (類似度: 0.7023)
#   3. ポピュラー音楽         (類似度: 0.6748)
#   4. 宗教音楽            (類似度: 0.6705)
#   5. 作曲家             (類似度: 0.6610)
#
# 【映画】に類似する単語 (Top 5):
#   1. 映画作品            (類似度: 0.7882)
#   2. ハリウッド映画         (類似度: 0.7528)
#   3. アメリカ映画          (類似度: 0.7359)
#   4. 長編映画            (類似度: 0.7082)
#   5. ヒット映画           (類似度: 0.7061)
#
# 【小説】に類似する単語 (Top 5):
#   1. 短編小説            (類似度: 0.8029)
#   2. 長編小説            (類似度: 0.7948)
#   3. 歴史小説            (類似度: 0.7646)
#   4. 恋愛小説            (類似度: 0.7048)
#   5. ミステリー小説         (類似度: 0.7035)
#
# 【経済】に類似する単語 (Top 5):
#   1. 中国経済            (類似度: 0.7015)
#   2. 世界経済            (類似度: 0.7011)
#   3. 地域経済            (類似度: 0.7008)
#   4. 経済構造            (類似度: 0.6666)
#   5. 経済政策            (類似度: 0.6661)
#
# 【政治】に類似する単語 (Top 5):
#   1. 地方政治            (類似度: 0.6780)
#   2. 政治的             (類似度: 0.6578)
#   3. 政治・経済           (類似度: 0.6456)
#   4. 外交              (類似度: 0.6417)
#   5. 政治過程            (類似度: 0.6156)
#
# 【科学】に類似する単語 (Top 5):
#   1. 自然科学            (類似度: 0.7099)
#   2. 科学技術            (類似度: 0.6899)
#   3. 科学ジャーナリズム       (類似度: 0.6758)
#   4. 精密科学            (類似度: 0.6731)
#   5. サイエンス           (類似度: 0.6720)
#
# 【大学】に類似する単語 (Top 5):
#   1. 工科              (類似度: 0.7163)
#   2. 州立大学            (類似度: 0.7060)
#   3. カレッジ            (類似度: 0.6789)
#   4. ユニバーシティー        (類似度: 0.6740)
#   5. 学部              (類似度: 0.6725)
#
# 【研究】に類似する単語 (Top 5):
#   1. 共同研究            (類似度: 0.7342)
#   2. 研究対象            (類似度: 0.7042)
#   3. 研究者             (類似度: 0.7041)
#   4. 基礎研究            (類似度: 0.6743)
#   5. 研究グループ          (類似度: 0.6333)
#
# 【教育】に類似する単語 (Top 5):
#   1. 学校教育            (類似度: 0.7492)
#   2. 高等教育            (類似度: 0.7207)
#   3. 初等教育            (類似度: 0.6873)
#   4. 家庭教育            (類似度: 0.6836)
#   5. 専門教育            (類似度: 0.6772)

# %%
# 単語類推テスト（アナロジー）
print("=" * 80)
print("単語類推テスト（Fullモデル）")
print("=" * 80)

analogy_tests = [
    # 地理的関係
    ("東京", "日本", "パリ", "東京:日本 = パリ:?"),
    ("大阪", "日本", "ニューヨーク", "大阪:日本 = ニューヨーク:?"),
    
    # 性別関係
    ("男性", "王", "女性", "男性:王 = 女性:?"),
    ("男", "俳優", "女", "男:俳優 = 女:?"),
    
    # サイズ関係
    ("大きい", "大", "小さい", "大きい:大 = 小さい:?"),
    ("高い", "高", "低い", "高い:高 = 低い:?"),
    
    # 時制関係
    ("現在", "今", "過去", "現在:今 = 過去:?"),
    
    # スポーツと選手
    ("野球", "選手", "サッカー", "野球:選手 = サッカー:?"),
    
    # 学問分野
    ("数学", "数", "物理", "数学:数 = 物理:?"),
]

for word1, word2, word3, description in analogy_tests:
    print(f"\n{description}")
    try:
        # word1 - word2 + word3 に近い単語
        result = full_model.wv.most_similar(
            positive=[word3, word2], 
            negative=[word1], 
            topn=5
        )
        print("  予測結果:")
        for i, (word, score) in enumerate(result, 1):
            print(f"    {i}. {word:15s} (スコア: {score:.4f})")
    except KeyError as e:
        print(f"  ⚠ エラー: 単語 {e} が語彙に含まれていません")
# Out:
# ================================================================================
# 単語類推テスト（Fullモデル）
# ================================================================================
#
# 東京:日本 = パリ:?
#   予測結果:
#     1. フランス            (スコア: 0.6036)
#     2. ヨーロッパ           (スコア: 0.4930)
#     3. ベルギー            (スコア: 0.4927)
#     4. リヨン             (スコア: 0.4682)
#     5. アンリ             (スコア: 0.4670)
#
# 大阪:日本 = ニューヨーク:?
#   予測結果:
#     1. アメリカ            (スコア: 0.5229)
#     2. アメリカ合衆国         (スコア: 0.4932)
#     3. 米国              (スコア: 0.4870)
#     4. ボストン            (スコア: 0.4746)
#     5. ニューヨーク市         (スコア: 0.4675)
#
# 男性:王 = 女性:?
#   ⚠ エラー: 単語 "Key '王' not present in vocabulary" が語彙に含まれていません
#
# 男:俳優 = 女:?
#   ⚠ エラー: 単語 "Key '女' not present in vocabulary" が語彙に含まれていません
#
# 大きい:大 = 小さい:?
#   ⚠ エラー: 単語 "Key '大' not present in vocabulary" が語彙に含まれていません
#
# 高い:高 = 低い:?
#   ⚠ エラー: 単語 "Key '高' not present in vocabulary" が語彙に含まれていません
#
# 現在:今 = 過去:?
#   ⚠ エラー: 単語 "Key '今' not present in vocabulary" が語彙に含まれていません
#
# 野球:選手 = サッカー:?
#   予測結果:
#     1. 代表選手            (スコア: 0.5797)
#     2. 若手選手            (スコア: 0.5751)
#     3. サッカー選手          (スコア: 0.5719)
#     4. レフトバック          (スコア: 0.5677)
#     5. ゴールキーパー         (スコア: 0.5677)
#
# 数学:数 = 物理:?
#   ⚠ エラー: 単語 "Key '数' not present in vocabulary" が語彙に含まれていません

# %%
# 単語間の類似度計算
print("=" * 80)
print("単語間の類似度計算（Fullモデル）")
print("=" * 80)

similarity_pairs = [
    # 同義語・類義語
    ("コンピュータ", "パソコン"),
    ("自動車", "車"),
    ("映画", "ムービー"),
    
    # 関連語
    ("東京", "日本"),
    ("野球", "スポーツ"),
    ("大学", "教育"),
    ("医者", "病院"),
    
    # 対義語
    ("大きい", "小さい"),
    ("高い", "低い"),
    ("良い", "悪い"),
    
    # 無関係な単語
    ("コンピュータ", "野球"),
    ("音楽", "経済"),
    ("映画", "数学"),
]

print("\n単語ペアの類似度:")
for word1, word2 in similarity_pairs:
    try:
        similarity = full_model.wv.similarity(word1, word2)
        print(f"  {word1:12s} ⟷ {word2:12s} : {similarity:.4f}")
    except KeyError as e:
        print(f"  {word1:12s} ⟷ {word2:12s} : エラー（単語 {e} が未登録）")
# Out:
# ================================================================================
# 単語間の類似度計算（Fullモデル）
# ================================================================================
#
# 単語ペアの類似度:
#   コンピュータ       ⟷ パソコン         : エラー（単語 "Key 'コンピュータ' not present" が未登録）
#   自動車          ⟷ 車            : エラー（単語 "Key '車' not present" が未登録）
#   映画           ⟷ ムービー         : 0.5482
#   東京           ⟷ 日本           : 0.3298
#   野球           ⟷ スポーツ         : 0.4874
#   大学           ⟷ 教育           : 0.3757
#   医者           ⟷ 病院           : 0.4211
#   大きい          ⟷ 小さい          : 0.6900
#   高い           ⟷ 低い           : 0.8752
#   良い           ⟷ 悪い           : 0.7657
#   コンピュータ       ⟷ 野球           : エラー（単語 "Key 'コンピュータ' not present" が未登録）
#   音楽           ⟷ 経済           : 0.2544
#   映画           ⟷ 数学           : 0.1636

# %%
# 仲間外れ検出テスト
print("=" * 80)
print("仲間外れ検出テスト（Fullモデル）")
print("=" * 80)

outlier_tests = [
    ["朝", "昼", "夜", "リンゴ"],
    ["東京", "大阪", "京都", "アメリカ"],
    ["野球", "サッカー", "テニス", "音楽"],
    ["犬", "猫", "鳥", "自動車"],
    ["赤", "青", "緑", "大きい"],
    ["春", "夏", "秋", "月曜日"],
]

print("\n仲間外れを検出:")
for words in outlier_tests:
    try:
        # 語彙に含まれる単語のみでフィルタ
        valid_words = [w for w in words if w in full_model.wv]
        if len(valid_words) < 2:
            print(f"  {words} : スキップ（語彙不足）")
            continue
            
        outlier = full_model.wv.doesnt_match(valid_words)
        print(f"  {words}")
        print(f"    → 仲間外れ: 【{outlier}】")
    except Exception as e:
        print(f"  {words} : エラー - {str(e)[:50]}")
# Out:
# ================================================================================
# 仲間外れ検出テスト（Fullモデル）
# ================================================================================
#
# 仲間外れを検出:
#   ['朝', '昼', '夜', 'リンゴ'] : スキップ（語彙不足）
#   ['東京', '大阪', '京都', 'アメリカ']
#     → 仲間外れ: 【アメリカ】
#   ['野球', 'サッカー', 'テニス', '音楽']
#     → 仲間外れ: 【音楽】
#   ['犬', '猫', '鳥', '自動車'] : スキップ（語彙不足）
#   ['赤', '青', '緑', '大きい'] : スキップ（語彙不足）
#   ['春', '夏', '秋', '月曜日'] : スキップ（語彙不足）

# %%
# 語彙統計情報
print("=" * 80)
print("Fullモデルの語彙統計")
print("=" * 80)

print("\n基本情報:")
print(f"  総語彙数: {len(full_model.wv):,}語")
print(f"  ベクトル次元: {full_model.wv.vector_size}")

print("\n頻出単語 Top 30:")
for i, word in enumerate(full_model.wv.index_to_key[:30], 1):
    print(f"  {i:2d}. {word}")

print("\n低頻度単語（末尾10語）:")
for i, word in enumerate(full_model.wv.index_to_key[-10:], 1):
    print(f"  {i:2d}. {word}")
# Out:
# ================================================================================
# Fullモデルの語彙統計
# ================================================================================
#
# 基本情報:
#   総語彙数: 393,381語
#   ベクトル次元: 300
#
# 頻出単語 Top 30:
#    1. 為る
#    2. れる
#    3. 居る
#    4. 有る
#    5. から
#    6. 成る
#    7. こと
#    8. よる
#    9. 言う
#   10. など
#   11. 其の
#   12. 此の
#   13. ない
#   14. られる
#   15. 無い
#   16. 行う
#   17. よう
#   18. まで
#   19. 此れ
#   20. 日本
#   21. 出来る
#   22. 10
#   23. おく
#   24. おる
#   25. より
#   26. せる
#   27. 12
#   28. 其れ
#   29. 11
#   30. 現在
#
# 低頻度単語（末尾10語）:
#    1. エスカレラ
#    2. 高野由美
#    3. 広島新庄高等学校
#    4. 199000
#    5. 新山志保
#    6. ジャン・ギャロン
#    7. penpoint
#    8. ジャーディ
#    9. 国家の品格
#   10. 渡辺勝彦

# %%
# 特定ドメインの単語クラスタリング分析
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# 日本語フォント設定
plt.rcParams['font.sans-serif'] = ['Hiragino Sans', 'Yu Gothic', 'Meirio', 'DejaVu Sans']
plt.rcParams['axes.unicode_minus'] = False

print("=" * 80)
print("特定ドメインの単語クラスタリング")
print("=" * 80)

# 分析対象の単語群
domain_words = {
    "都市": ["東京", "大阪", "京都", "名古屋", "福岡", "札幌", "横浜", "神戸"],
    "スポーツ": ["野球", "サッカー", "テニス", "バスケットボール", "バレーボール", "ゴルフ"],
    "学問": ["数学", "物理", "化学", "生物", "歴史", "地理", "文学"],
    "色": ["赤", "青", "緑", "黄色", "黒", "白", "紫", "オレンジ"],
}

# 語彙に存在する単語のみ抽出
all_words = []
word_labels = []
for category, words in domain_words.items():
    for word in words:
        if word in full_model.wv:
            all_words.append(word)
            word_labels.append(category)

if len(all_words) > 0:
    # 単語ベクトルを取得
    word_vectors = np.array([full_model.wv[word] for word in all_words])
    
    # t-SNEで2次元に圧縮
    print(f"\n{len(all_words)}語をt-SNEで可視化中...")
    tsne = TSNE(n_components=2, random_state=42, perplexity=min(30, len(all_words)-1))
    word_vectors_2d = tsne.fit_transform(word_vectors)
    
    # カテゴリごとに色分けしてプロット
    plt.figure(figsize=(14, 10))
    colors = ['red', 'blue', 'green', 'orange', 'purple', 'brown', 'pink', 'gray']
    category_colors = {cat: colors[i % len(colors)] for i, cat in enumerate(domain_words.keys())}
    
    for i, (word, category) in enumerate(zip(all_words, word_labels)):
        x, y = word_vectors_2d[i]
        plt.scatter(x, y, c=category_colors[category], s=100, alpha=0.6)
        plt.annotate(word, xy=(x, y), xytext=(5, 5), 
                    textcoords='offset points', fontsize=11, alpha=0.8)
    
    # 凡例
    from matplotlib.patches import Patch
    legend_elements = [Patch(facecolor=category_colors[cat], label=cat) 
                      for cat in domain_words.keys()]
    plt.legend(handles=legend_elements, loc='best', fontsize=10)
    
    plt.title('単語ベクトルのクラスタリング可視化（カテゴリ別）', fontsize=14)
    plt.xlabel('次元1')
    plt.ylabel('次元2')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    print("✓ 可視化完了")
else:
    print("⚠ 語彙に含まれる単語が見つかりませんでした")
# Out:
# ================================================================================
# 特定ドメインの単語クラスタリング
# ================================================================================
#
# 23語をt-SNEで可視化中...
# ✓ 可視化完了

# %%
# カスタム単語検索（インタラクティブ）
print("=" * 80)
print("カスタム単語検索")
print("=" * 80)

def search_similar_words(word, topn=10):
    """指定した単語の類似語を検索"""
    if word not in full_model.wv:
        print(f"⚠ 単語「{word}」は語彙に含まれていません")
        
        # 部分一致で候補を提案
        candidates = [w for w in full_model.wv.index_to_key[:10000] if word in w]
        if candidates:
            print("\n類似の単語候補（部分一致）:")
            for i, candidate in enumerate(candidates[:10], 1):
                print(f"  {i}. {candidate}")
        return
    
    print(f"\n【{word}】に類似する単語 (Top {topn}):")
    similar_words = full_model.wv.most_similar(word, topn=topn)
    for i, (similar_word, score) in enumerate(similar_words, 1):
        print(f"  {i:2d}. {similar_word:20s} (類似度: {score:.4f})")

# テスト検索
test_queries = ["人工知能", "機械学習", "プログラミング"]
for query in test_queries:
    search_similar_words(query, topn=10)
    print()
# Out:
# ================================================================================
# カスタム単語検索
# ================================================================================
#
# 【人工知能】に類似する単語 (Top 10):
#    1. ロボット工学               (類似度: 0.6671)
#    2. AI                   (類似度: 0.6656)
#    3. ディープラーニング            (類似度: 0.6583)
#    4. 機械学習                 (類似度: 0.6576)
#    5. ロドニー・ブルックス           (類似度: 0.6542)
#    6. 人工意識                 (類似度: 0.6473)
#    7. マービン・ミンスキー           (類似度: 0.6468)
#    8. アーティフィシャルインテリジェンス    (類似度: 0.6464)
#    9. クレバーボット              (類似度: 0.6409)
#   10. 自然言語処理               (類似度: 0.6401)
#
#
# 【機械学習】に類似する単語 (Top 10):
#    1. 深層学習                 (類似度: 0.7887)
#    2. Neural Network       (類似度: 0.7827)
#    3. データマイニング             (類似度: 0.7708)
#    4. データ駆動                (類似度: 0.7569)
#    5. 抽象解釈                 (類似度: 0.7567)
#    6. ファジィ制御               (類似度: 0.7541)
#    7. モデルベーステスト            (類似度: 0.7489)
#    8. 線形計画法                (類似度: 0.7471)
#    9. 言語モデル                (類似度: 0.7466)
#   10. 数理モデル                (類似度: 0.7461)
#
#
# 【プログラミング】に類似する単語 (Top 10):
#    1. プログラミング言語            (類似度: 0.7367)
#    2. コンピュータ言語             (類似度: 0.6851)
#    3. 関数プログラミング            (類似度: 0.6810)
#    4. プログラミングパラダイム         (類似度: 0.6798)
#    5. 関数型プログラミング           (類似度: 0.6735)
#    6. scratch              (類似度: 0.6704)
#    7. プログラミングツール           (類似度: 0.6685)
#    8. コンパイラー               (類似度: 0.6680)
#    9. 制約論理プログラミング          (類似度: 0.6679)
#   10. オブジェクト指向プログラミング      (類似度: 0.6650)

# %%
# ベクトル演算テスト（複雑な類推）
print("=" * 80)
print("ベクトル演算テスト（複雑な類推）")
print("=" * 80)

def vector_analogy(positive_words, negative_words, topn=5):
    """
    ベクトル演算による類推
    positive_words: 足す単語のリスト
    negative_words: 引く単語のリスト
    """
    try:
        result = full_model.wv.most_similar(
            positive=positive_words,
            negative=negative_words,
            topn=topn
        )
        
        pos_str = " + ".join(positive_words)
        neg_str = " - ".join(negative_words)
        print(f"\n{pos_str} - {neg_str} =")
        
        for i, (word, score) in enumerate(result, 1):
            print(f"  {i}. {word:20s} (スコア: {score:.4f})")
            
    except KeyError as e:
        print(f"\n⚠ エラー: 単語 {e} が語彙に含まれていません")

# 複雑な類推テスト
print("\n【地理的関係】")
vector_analogy(["パリ", "日本"], ["フランス"])

print("\n【職業と性別】")
vector_analogy(["女性", "医者"], ["男性"])

print("\n【時間的関係】")
vector_analogy(["未来", "過去"], ["現在"])

print("\n【学問分野】")
vector_analogy(["物理学", "数"], ["数学"])

print("\n【スポーツと道具】")
vector_analogy(["サッカー", "野球"], ["ボール"])
# Out:
# ================================================================================
# ベクトル演算テスト（複雑な類推）
# ================================================================================
#
# 【地理的関係】
#
# パリ + 日本 - フランス =
#   1. 日本国内                 (スコア: 0.4980)
#   2. 東京                   (スコア: 0.4685)
#   3. 国際浮世絵学会              (スコア: 0.4496)
#   4. 太平洋美術会               (スコア: 0.4495)
#   5. 日本南画院                (スコア: 0.4482)
#
# 【職業と性別】
#
# 女性 + 医者 - 男性 =
#   1. 医師                   (スコア: 0.6236)
#   2. 名医                   (スコア: 0.5409)
#   3. 藪医者                  (スコア: 0.5174)
#   4. 眼科医                  (スコア: 0.5024)
#   5. 往診                   (スコア: 0.5010)
#
# 【時間的関係】
#
# 未来 + 過去 - 現在 =
#   1. 時間跳躍                 (スコア: 0.4593)
#   2. 野上良太郎                (スコア: 0.4525)
#   3. 地球の危機                (スコア: 0.4486)
#   4. 時間軸                  (スコア: 0.4399)
#   5. 衛宮士郎                 (スコア: 0.4326)
#
# 【学問分野】
#
# ⚠ エラー: 単語 "Key '数' not present in vocabulary" が語彙に含まれていません
#
# 【スポーツと道具】
#
# サッカー + 野球 - ボール =
#   1. バレーボール               (スコア: 0.6367)
#   2. バスケットボール             (スコア: 0.6149)
#   3. ラグビー                 (スコア: 0.5840)
#   4. クラブチーム               (スコア: 0.5779)
#   5. 陸上競技                 (スコア: 0.5763)

# %%
# モデル性能の定量評価
print("=" * 80)
print("モデル性能の定量評価")
print("=" * 80)

# 類似度相関テスト用のデータ
similarity_test_data = [
    # (単語1, 単語2, 期待される類似度レベル: high/medium/low)
    ("コンピュータ", "パソコン", "high"),
    ("自動車", "車", "high"),
    ("東京", "日本", "high"),
    ("野球", "スポーツ", "medium"),
    ("医者", "病院", "medium"),
    ("音楽", "映画", "medium"),
    ("コンピュータ", "野球", "low"),
    ("音楽", "数学", "low"),
]

print("\n類似度スコア分布:")
high_scores = []
medium_scores = []
low_scores = []

for word1, word2, level in similarity_test_data:
    try:
        score = full_model.wv.similarity(word1, word2)
        print(f"  {word1:15s} ⟷ {word2:15s} : {score:.4f} ({level})")
        
        if level == "high":
            high_scores.append(score)
        elif level == "medium":
            medium_scores.append(score)
        else:
            low_scores.append(score)
    except KeyError:
        print(f"  {word1:15s} ⟷ {word2:15s} : スキップ（語彙なし）")

# 統計サマリ
if high_scores:
    print(f"\n高関連語ペアの平均類似度: {np.mean(high_scores):.4f} (±{np.std(high_scores):.4f})")
if medium_scores:
    print(f"中関連語ペアの平均類似度: {np.mean(medium_scores):.4f} (±{np.std(medium_scores):.4f})")
if low_scores:
    print(f"低関連語ペアの平均類似度: {np.mean(low_scores):.4f} (±{np.std(low_scores):.4f})")

# 分離度の評価
if high_scores and low_scores:
    separation = np.mean(high_scores) - np.mean(low_scores)
    print(f"\n分離度（高-低）: {separation:.4f}")
    print("  → 値が大きいほど、関連語と無関連語を区別できている")
# Out:
# ================================================================================
# モデル性能の定量評価
# ================================================================================
#
# 類似度スコア分布:
#   コンピュータ          ⟷ パソコン            : スキップ（語彙なし）
#   自動車             ⟷ 車               : スキップ（語彙なし）
#   東京              ⟷ 日本              : 0.3298 (high)
#   野球              ⟷ スポーツ            : 0.4874 (medium)
#   医者              ⟷ 病院              : 0.4211 (medium)
#   音楽              ⟷ 映画              : 0.4225 (medium)
#   コンピュータ          ⟷ 野球              : スキップ（語彙なし）
#   音楽              ⟷ 数学              : 0.3732 (low)
#
# 高関連語ペアの平均類似度: 0.3298 (±0.0000)
# 中関連語ペアの平均類似度: 0.4437 (±0.0310)
# 低関連語ペアの平均類似度: 0.3732 (±0.0000)
#
# 分離度（高-低）: -0.0434
#   → 値が大きいほど、関連語と無関連語を区別できている

# %% [markdown]
# ## 単語ベクトルの可視化 (t-SNE)

# %%
# 頻出単語の可視化（t-SNE）- Fullモデル
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# 日本語フォント設定
plt.rcParams['font.sans-serif'] = ['Hiragino Sans', 'Yu Gothic', 'Meirio', 'DejaVu Sans']
plt.rcParams['axes.unicode_minus'] = False

# Fullモデルを使用
try:
    viz_model = full_model
    print(f"使用モデル: full_model (語彙数: {len(viz_model.wv):,}語)")
except NameError:
    print("⚠ full_modelが見つかりません。先にモデルを読み込んでください。")
    viz_model = None

if viz_model is not None:
    # 頻出上位500語を可視化
    vocab_size = min(500, len(viz_model.wv))
    words = list(viz_model.wv.index_to_key[:vocab_size])
    word_vectors = np.array([viz_model.wv[word] for word in words])
    
    print(f"\n{vocab_size}語をt-SNEで2次元に圧縮中...")
    # n_iter → max_iter に修正
    tsne = TSNE(n_components=2, random_state=42, perplexity=30, max_iter=1000)
    word_vectors_2d = tsne.fit_transform(word_vectors)
    
    # プロット
    plt.figure(figsize=(20, 20))
    plt.scatter(word_vectors_2d[:, 0], word_vectors_2d[:, 1], alpha=0.3, s=10, c='blue')
    
    # 一部の単語をラベル表示（100語）
    for i in range(0, min(100, vocab_size)):
        plt.annotate(words[i], 
                    xy=(word_vectors_2d[i, 0], word_vectors_2d[i, 1]),
                    fontsize=8,
                    alpha=0.7)
    
    plt.title(f'Word2Vec 単語ベクトルの可視化 (t-SNE) - 頻出{vocab_size}語 [Fullモデル]', fontsize=16)
    plt.xlabel('次元1')
    plt.ylabel('次元2')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    print(f"✓ {vocab_size}語を可視化しました")
# Out:
# 使用モデル: full_model (語彙数: 393,381語)
#
# 500語をt-SNEで2次元に圧縮中...
# ✓ 500語を可視化しました

# %%
# カテゴリ別の単語可視化（色分け）- Fullモデル
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import numpy as np

# カテゴリ別の単語リスト
categories = {
    "地名": ["日本", "東京", "大阪", "京都", "名古屋", "福岡", "札幌", "横浜", "神戸", "広島",
            "アメリカ", "中国", "韓国", "フランス", "イギリス", "ドイツ", "パリ", "ロンドン"],
    
    "スポーツ": ["野球", "サッカー", "テニス", "バスケットボール", "バレーボール", "ゴルフ", 
                "水泳", "陸上", "柔道", "剣道", "スポーツ", "選手", "試合", "優勝"],
    
    "学問": ["数学", "物理", "化学", "生物", "歴史", "地理", "文学", "哲学", "経済", "政治",
            "科学", "研究", "大学", "教育", "学校", "教授"],
    
    "技術": ["コンピュータ", "プログラミング", "人工知能", "機械学習", "データ", "システム",
            "ソフトウェア", "ハードウェア", "ネットワーク", "インターネット", "技術", "開発"],
    
    "文化": ["音楽", "映画", "小説", "漫画", "アニメ", "ゲーム", "芸術", "文化", "芸能",
            "テレビ", "ラジオ", "新聞"],
    
    "自然": ["山", "川", "海", "森", "空", "雲", "雨", "雪", "風", "太陽", "月", "星",
            "動物", "植物", "花", "木"],
}

# 語彙に存在する単語のみ抽出
all_words = []
word_labels = []
word_colors = []

color_map = {
    "地名": "red",
    "スポーツ": "blue", 
    "学問": "green",
    "技術": "purple",
    "文化": "orange",
    "自然": "brown"
}

for category, words_list in categories.items():
    for word in words_list:
        if word in full_model.wv:
            all_words.append(word)
            word_labels.append(category)
            word_colors.append(color_map[category])

print(f"語彙に存在する単語: {len(all_words)}語")

if len(all_words) > 1:
    # 単語ベクトルを取得
    word_vectors = np.array([full_model.wv[word] for word in all_words])
    
    # t-SNEで2次元に圧縮（max_iterに修正）
    print(f"{len(all_words)}語をt-SNEで可視化中...")
    perplexity = min(30, len(all_words) - 1)
    tsne = TSNE(n_components=2, random_state=42, perplexity=perplexity, max_iter=1000)
    word_vectors_2d = tsne.fit_transform(word_vectors)
    
    # プロット
    plt.figure(figsize=(18, 14))
    
    # カテゴリごとにプロット
    for category in categories.keys():
        indices = [i for i, label in enumerate(word_labels) if label == category]
        if indices:
            x = word_vectors_2d[indices, 0]
            y = word_vectors_2d[indices, 1]
            plt.scatter(x, y, c=color_map[category], label=category, s=100, alpha=0.6)
    
    # 単語ラベルを表示
    for i, word in enumerate(all_words):
        plt.annotate(word, 
                    xy=(word_vectors_2d[i, 0], word_vectors_2d[i, 1]),
                    xytext=(3, 3),
                    textcoords='offset points',
                    fontsize=10,
                    alpha=0.8)
    
    plt.title('カテゴリ別 単語ベクトルの可視化 (t-SNE) [Fullモデル]', fontsize=16)
    plt.xlabel('次元1')
    plt.ylabel('次元2')
    plt.legend(loc='best', fontsize=12)
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    print("✓ カテゴリ別可視化完了")
else:
    print("⚠ 語彙に含まれる単語が不足しています")
# Out:
# 語彙に存在する単語: 74語
# 74語をt-SNEで可視化中...
# ✓ カテゴリ別可視化完了
